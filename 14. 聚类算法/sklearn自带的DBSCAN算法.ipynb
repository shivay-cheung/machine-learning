# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

#载入数据
data = np.genfromtxt("kmeans.csv",delimiter=',')
# print(data)

#加载模型 并训练模型
model = DBSCAN(eps=2.2,min_samples=4)
model.fit(data)

#
result = model.fit_predict(data)
print(result)

#画出各个数据点 ，并用不同颜色将其表示出来
mark = ['or','ob','og','oy','ok','om']

for i,d in enumerate(data):
    plt.plot(d[0],d[1],mark[result[i]])
plt.show()
# Out:
# [0 3 1 2 0 3 1 2 0 3 3 2 0 3 1 2 0 3 1 2 0 3 1 2 0 3 1 2 0 3 1 2 0]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import datasets

#加载数据
x1,y1 = datasets.make_circles(n_samples=2000,factor=0.5,noise=0.05)
x2,y2 = datasets.make_blobs(n_samples=1000,centers=[[1.2,1.2]],cluster_std=[[.1]])

x = np.concatenate((x1,x2))
plt.scatter(x[:,0],x[:,1],marker='o')
plt.show()

#---------------------- 创建 Kmenas 模型 并训练 ---------------------- 
print("Kmenas 模型训练结果：")
y_pred = KMeans(n_clusters=3).fit_predict(x)
plt.scatter(x[:,0],x[:,1],c=y_pred)
plt.show()

#---------------------- 创建 DBSCAN 模型 并训练 ---------------------- 
print("DBSCAN 模型训练结果：")
y_pred = DBSCAN(eps=0.2,min_samples=50).fit_predict(x)
plt.scatter(x[:,0],x[:,1],c=y_pred)
plt.show()
# Out:
# Kmenas 模型训练结果：
# DBSCAN 模型训练结果：
